# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Madiha Kounain\Documents\project\employee_attrition_data.csv")

# %%
print(df)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0              0   27    Male    Marketing        Manager                 9
# 1              1   53  Female        Sales       Engineer                10
# 2              2   59  Female    Marketing        Analyst                 8
# 3              3   42  Female  Engineering        Manager                 1
# 4              4   44  Female        Sales       Engineer                10
# ..           ...  ...     ...          ...            ...               ...
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0              0.586251                    151                      0   60132
# 1              0.261161                    221                      1   79947
# 2              0.304382                    184                      0   46958
# 3              0.480779                    242                      0   40662
# 4              0.636244                    229                      1   74307
# ..                  ...                    ...                    ...     ...
# 995            0.377435                    239                      0   71403
# 996            0.431152                    154                      0   30181
# 997            0.647102                    206                      0   64143
# 998            0.304813                    241                      0   74383
# 999            0.940510                    159                      0   73220
#
#      Attrition
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0
# ..         ...
# 995          0
# 996          1
# 997          0
# 998          1
# 999          1
#
# [1000 rows x 11 columns]

# %%
print(df.head(10))
# Out:
#    Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing        Manager                 9
# 1            1   53  Female        Sales       Engineer                10
# 2            2   59  Female    Marketing        Analyst                 8
# 3            3   42  Female  Engineering        Manager                 1
# 4            4   44  Female        Sales       Engineer                10
# 5            5   47    Male        Sales  HR Specialist                10
# 6            6   58    Male    Marketing  HR Specialist                 5
# 7            7   57  Female        Sales        Analyst                 8
# 8            8   34  Female      Finance     Accountant                 6
# 9            9   57  Female    Marketing       Engineer                 7
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
# 5            0.889018                    237                      0   97212
# 6            0.688977                    155                      1   97865
# 7            0.981679                    171                      0   50113
# 8            0.010381                    177                      1   88747
# 9            0.466782                    170                      0   43283
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# 5          0
# 6          0
# 7          0
# 8          1
# 9          0

# %%
print(df.tail(10))
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 990          990   36  Female  Engineering     Accountant                 9
# 991          991   47    Male    Marketing        Manager                 2
# 992          992   46  Female           HR        Analyst                 8
# 993          993   47  Female           HR        Analyst                 5
# 994          994   47    Male    Marketing  HR Specialist                 2
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 990            0.558512                    182                      1   65638
# 991            0.889621                    243                      0   78726
# 992            0.955095                    176                      1   79044
# 993            0.932450                    193                      0   47301
# 994            0.992018                    186                      1   31507
# 995            0.377435                    239                      0   71403
# 996            0.431152                    154                      0   30181
# 997            0.647102                    206                      0   64143
# 998            0.304813                    241                      0   74383
# 999            0.940510                    159                      0   73220
#
#      Attrition
# 990          1
# 991          1
# 992          1
# 993          0
# 994          0
# 995          0
# 996          1
# 997          0
# 998          1
# 999          1

# %%
print(df.columns)
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Title',
#        'Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours',
#        'Promotion_Last_5Years', 'Salary', 'Attrition'],
#       dtype='object')

# %%
df.isna()
# Out:
#      Employee_ID    Age  Gender  Department  Job_Title  Years_at_Company  \
# 0          False  False   False       False      False             False
# 1          False  False   False       False      False             False
# 2          False  False   False       False      False             False
# 3          False  False   False       False      False             False
# 4          False  False   False       False      False             False
# ..           ...    ...     ...         ...        ...               ...
# 995        False  False   False       False      False             False
# 996        False  False   False       False      False             False
# 997        False  False   False       False      False             False
# 998        False  False   False       False      False             False
# 999        False  False   False       False      False             False
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0                 False                  False                  False   False
# 1                 False                  False                  False   False
# 2                 False                  False                  False   False
# 3                 False                  False                  False   False
# 4                 False                  False                  False   False
# ..                  ...                    ...                    ...     ...
# 995               False                  False                  False   False
# 996               False                  False                  False   False
# 997               False                  False                  False   False
# 998               False                  False                  False   False
# 999               False                  False                  False   False
#
#      Attrition
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 995      False
# 996      False
# 997      False
# 998      False
# 999      False
#
# [1000 rows x 11 columns]

# %%
print(df.head())
# Out:
#    Employee_ID  Age  Gender   Department Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing   Manager                 9
# 1            1   53  Female        Sales  Engineer                10
# 2            2   59  Female    Marketing   Analyst                 8
# 3            3   42  Female  Engineering   Manager                 1
# 4            4   44  Female        Sales  Engineer                10
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns='Employee_ID',inplace=True)

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\madiha kounain\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\madiha kounain\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\madiha kounain\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\madiha kounain\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\madiha kounain\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\madiha kounain\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\madiha kounain\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\madiha kounain\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\madiha kounain\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\madiha kounain\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\madiha kounain\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt

# %%
df['Gender'].value_counts().plot(kind='pie')
plt.ylabel("")
plt.title("Gender Count of Employees")
plt.show()

# %%
df['Job_Title'].value_counts().plot(kind='bar')
plt.ylabel("")
plt.title("Job titles  of Employees")
plt.show()

# %%
df['Department'].value_counts().plot(kind='line')
plt.ylabel("")
plt.title("Departments")
plt.show()

# %%
df['Years_at_Company'].value_counts().plot(kind='pie')
plt.ylabel("")
plt.title("Years_at_Company")
plt.show()

# %%
df.groupby('Job_Title')['Salary'].mean().sort_values(ascending=False).plot(kind='line')
plt.title("Average Salary as Job Title")
plt.xlabel('Job title')
plt.ylabel('Average Salary')
plt.show()

# %%
df.groupby(['Department','Promotion_Last_5Years'])['Salary'].mean().reset_index()
# Out:
#     Department  Promotion_Last_5Years        Salary
# 0  Engineering                      0  65541.063636
# 1  Engineering                      1  62424.127660
# 2      Finance                      0  63390.145299
# 3      Finance                      1  62041.269663
# 4           HR                      0  63012.556701
# 5           HR                      1  65882.861702
# 6    Marketing                      0  65251.597826
# 7    Marketing                      1  66018.632653
# 8        Sales                      0  64295.846939
# 9        Sales                      1  67838.756757

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
x=df[['Years_at_Company','Satisfaction_Level','Average_Monthly_Hours']]
y=df['Salary']

# %%
! pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\madiha kounain\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\madiha kounain\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\madiha kounain\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\madiha kounain\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\madiha kounain\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.19295287, -0.66420383,  1.32819532],
#        [ 1.54799837,  1.69386524, -1.44469033],
#        [-0.22722912, -0.36428851,  0.75332878],
#        ...,
#        [ 0.48286188,  0.89683336,  1.56490507],
#        [-0.58227462,  0.57572379, -0.90363947],
#        [-0.93732011, -0.08978386, -1.47850601]])

# %%
import joblib
joblib.dump(scaler,'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
x_test=scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-0.86994597, -0.40036656,  0.61872965],
#        [-1.22286523, -0.62647273, -0.72450975],
#        [-0.16410745, -0.23962935, -1.02673862],
#        [ 0.1888118 , -1.09061793,  1.25676837],
#        [-0.51702671, -0.9815222 ,  0.11501487],
#        [ 1.24756957, -1.31564417, -0.69092877],
#        [ 0.1888118 , -1.68494161,  1.59257822],
#        [-1.57578448,  1.04511031,  0.5179867 ],
#        [-0.16410745,  1.75342028, -1.32896749],
#        [ 0.1888118 , -0.70229993, -1.02673862],
#        [-0.86994597, -0.41724209,  0.78663458],
#        [-1.57578448, -0.42903139,  0.11501487],
#        [-0.16410745, -0.71328486, -0.3886999 ],
#        [ 0.54173106,  1.07423548, -0.3886999 ],
#        [-0.16410745, -1.74613701,  1.42467329],
#        [ 0.54173106, -0.07290836, -1.26180552],
#        [-0.86994597,  0.57440928,  0.35008177],
#        [ 0.54173106, -0.12908907, -0.12005202],
#        [-0.51702671, -0.41933018,  0.41724374],
#        [ 0.54173106,  1.54037573,  0.41724374],
#        [ 1.60048883,  0.01221786, -0.6237668 ],
#        [ 0.54173106,  0.16590849,  0.14859586],
#        [-0.16410745,  1.19927575, -0.45586187],
#        [-0.51702671, -1.20274931, -0.99315764],
#        [ 0.54173106, -1.41571879, -0.52302384],
#        [ 0.89465032, -0.59384799, -1.42971044],
#        [ 0.1888118 ,  0.98122239, -0.89241468],
#        [ 1.24756957,  0.21700104, -0.99315764],
#        [-1.57578448, -1.5219578 , -0.99315764],
#        [-1.57578448, -0.47596926, -0.99315764],
#        [-1.22286523, -0.11454598,  1.55899724],
#        [ 1.24756957, -0.13903632, -1.32896749],
#        [ 1.24756957,  0.29878785, -1.59761537],
#        [-0.86994597, -0.43539389,  1.35751132],
#        [-0.16410745,  0.48611808,  0.55156768],
#        [-1.22286523, -1.01409902,  0.71947261],
#        [-1.57578448, -0.75755143, -1.42971044],
#        [-1.22286523, -0.62098791, -0.3886999 ],
#        [-0.51702671, -1.53106796, -0.82525271],
#        [ 1.24756957, -1.19658438, -1.49687241],
#        [ 1.60048883, -0.23955591,  1.35751132],
#        [-0.16410745,  1.49557983,  0.55156768],
#        [-1.57578448,  0.34028456,  0.9545395 ],
#        [-0.51702671, -1.68101756,  0.0478529 ],
#        [-0.51702671, -1.2288163 , -1.63119635],
#        [-1.22286523,  0.95049137, -0.59018581],
#        [-1.22286523,  1.60755089,  1.22318738],
#        [ 1.60048883,  0.37158032,  0.65231064],
#        [-0.16410745,  1.65916161, -0.69092877],
#        [-1.57578448,  1.57651963, -0.01930907],
#        [ 0.54173106, -0.2609748 ,  1.29034935],
#        [ 0.89465032, -0.60186458, -1.22822453],
#        [-0.16410745,  1.10706249,  0.08143389],
#        [-0.16410745,  0.30807827,  1.25676837],
#        [-0.51702671,  0.14232972, -0.48944286],
#        [-0.86994597, -1.39307267,  1.45825428],
#        [ 0.1888118 , -0.12998584,  0.88737753],
#        [-0.86994597, -0.9363404 ,  1.32393034],
#        [ 1.24756957, -1.01620681, -1.22822453],
#        [ 1.60048883, -1.13472108, -1.63119635],
#        [-1.22286523,  0.68487669, -1.16106256],
#        [ 1.60048883, -0.11818189, -0.32153793],
#        [ 0.1888118 ,  0.48089179,  1.29034935],
#        [ 0.89465032,  0.59165911,  1.15602541],
#        [ 0.89465032, -1.50035968, -0.28795695],
#        [ 1.60048883, -0.97485167,  0.24933881],
#        [-0.51702671,  0.77061195,  0.78663458],
#        [ 0.89465032,  0.52120511, -1.26180552],
#        [-1.22286523, -0.38134812, -1.5304534 ],
#        [ 0.89465032,  1.64676336,  1.22318738],
#        [-1.22286523,  0.5286512 , -0.32153793],
#        [-0.16410745,  1.31194993, -0.12005202],
#        [-1.22286523,  0.71609713, -1.63119635],
#        [ 0.1888118 ,  1.64814093,  0.78663458],
#        [-0.51702671,  0.13022901,  0.92095852],
#        [ 1.24756957,  0.78922771,  0.11501487],
#        [ 1.24756957,  1.62660966,  0.38366276]])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
def results(predictions):
    print("Mean absolute error on model is {}".format(mean_absolute_error(y_test,predictions)))
    print("Root Mean squared error on model is {}".format(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
predictionlr=lr.predict(x_test)
results(predictionlr)
# Out:
# Mean absolute error on model is 17278.368312527688
# Root Mean squared error on model is 20199.05961797008

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# %%
svrmodel=SVR()

# %%
param_gridsvr={
    'C':[0.1,1,10],
    'epsilon':[0.1,0.2,0.5],
    'kernel':['linear','poly','rbf'],
    'degree':[2,3,4],
}

# %%
gridsvr=GridSearchCV(svrmodel,param_gridsvr)

# %%
gridsvr.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.5],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rfmodel=RandomForestRegressor()

# %%
param_gridfr={
    'n_estimators':[2,3,4,5,6],
    'max_depth':[5,10,15]
}

# %%
gridfr=GridSearchCV(estimator=rfmodel,param_grid=param_gridfr,cv=5)

# %%
gridfr.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6]})

# %%
gridfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 6}

# %%
predictionofrfr=gridfr.predict(x_test)

# %%
results(predictionofrfr)
# Out:
# Mean absolute error on model is 17828.216913339387
# Root Mean squared error on model is 20979.46074798782

# %%
joblib.dump(lr,'model.pkl')
# Out:
# ['model.pkl']

# %%
x.columns
# Out:
# Index(['Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours'], dtype='object')
